# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.points import reconstruction_from_dataset
dataset_name = "stereo_budha_charuco"

# %%
reconstruction_from_dataset(dataset_name)
# Out:
# Iniciando procesamiento de 21 pares de imágenes...
# --- Presiona 'ESC' en las ventanas de imagen para saltar al final ---
#
# --- Procesando Frame 1/21 ---
# *************** EP Error ***************
# EP Error /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:129 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] /onnxruntime_src/onnxruntime/core/providers/cuda/cuda_call.cc:121 std::conditional_t<THRW, void, onnxruntime::common::Status> onnxruntime::CudaCall(ERRTYPE, const char*, const char*, SUCCTYPE, const char*, const char*, int) [with ERRTYPE = cudaError; bool THRW = true; SUCCTYPE = cudaError; std::conditional_t<THRW, void, common::Status> = void] CUDA failure 35: CUDA driver version is insufficient for CUDA runtime version ; GPU=-1 ; hostname=juanchi-Aspire-A315-44P ; file=/onnxruntime_src/onnxruntime/core/providers/cuda/cuda_execution_provider.cc ; line=282 ; expr=cudaSetDevice(info_.device_id);
#
#  when using ['CUDAExecutionProvider', 'CPUExecutionProvider']
# Falling back to ['CPUExecutionProvider'] and retrying.
# ****************************************
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 344.08  301.69 -288.97]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 2/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 351.76  215.13 -301.74]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 3/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 374.9   151.23 -311.52]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 4/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 382.55   61.71 -319.53]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 5/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 317.23   -3.79 -317.72]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 6/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 237.82  -92.06 -333.34]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 7/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 113.97  -97.4  -322.2 ]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 8/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [   1.72  -84.05 -314.61]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 9/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ -82.78  -33.35 -303.01]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 10/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [-121.21   41.47 -306.39]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 11/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [-119.15  142.58 -301.94]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 12/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [-137.18  300.34 -340.95]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 13/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [-145.68  436.2  -362.46]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 14/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ -56.69  461.53 -340.99]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 15/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [  66.52  559.35 -345.76]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 16/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 218.12  574.03 -363.48]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 17/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 343.29  520.29 -368.97]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 18/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 407.31  415.57 -345.1 ]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 19/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 432.68  327.47 -269.59]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 20/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 438.05  263.39 -204.5 ]
# (i) PUNTOS 3D generados en este frame: 2073600
#
# --- Procesando Frame 21/21 ---
# (i) POSE OK. Posición de cámara (X,Y,Z en milimetros): [ 371.2   204.75 -353.99]
# (i) PUNTOS 3D generados en este frame: 2073600
# Combinando nubes de puntos...
# Puntos guardados en: datasets/stereo_budha_charuco/data/results/points.npy
# Poses guardadas en: datasets/stereo_budha_charuco/data/results/poses.npy

# %%
import numpy as np
import open3d as o3d
import json
import pickle
from pathlib import Path

DATASETS_PATH = "datasets"

print("Cargando parámetros de calibración (JSON y PKL)...")
json_path = f"{DATASETS_PATH}/{dataset_name}/data/rect/stereo_calibration.json"
maps_path = f"{DATASETS_PATH}/{dataset_name}/data/stereo_maps.pkl"

with open(json_path, "r") as f:
    data = json.load(f)
with open(maps_path, "rb") as f:
    maps = pickle.load(f)

rectified_K = maps['P1'][:, :3]
IMAGE_WIDTH = data['width']
IMAGE_HEIGHT = data['height']

points_filename = f"{DATASETS_PATH}/{dataset_name}/data/results/points.npy"
poses_filename = f"{DATASETS_PATH}/{dataset_name}/data/results/poses.npy"

print(f"Cargando puntos desde {points_filename}")
points_array = np.load(points_filename)

print(f"Cargando poses desde {poses_filename}")
poses_array = np.load(poses_filename)

print("Carga completa.")
# Out:
# Cargando parámetros de calibración (JSON y PKL)...
# Cargando puntos desde datasets/stereo_budha_charuco/data/results/points.npy
# Cargando poses desde datasets/stereo_budha_charuco/data/results/poses.npy
# Carga completa.

# %%
pcd = o3d.geometry.PointCloud()
pcd.points = o3d.utility.Vector3dVector(points_array)

# %%
camera_geometries = []

for o_T_c in poses_array:
    camera_viz = o3d.geometry.LineSet.create_camera_visualization(
        IMAGE_WIDTH,
        IMAGE_HEIGHT,
        rectified_K,
        np.linalg.inv(o_T_c),
        scale=100
    )
    camera_geometries.append(camera_viz)

world_frame = o3d.geometry.TriangleMesh.create_coordinate_frame(
    size=200, origin=[0, 0, 0]
)

# %%
o3d.visualization.draw_plotly([world_frame] + camera_geometries)

# %%
min_bound = np.array([9.0940, 97.4893, -278.2406])
max_bound = np.array([210.4005, 282.3002, -5.0915])

buddha_box = o3d.geometry.AxisAlignedBoundingBox(min_bound, max_bound)

# %%
indices_in_box = buddha_box.get_point_indices_within_bounding_box(pcd.points)
buddha_pcd = pcd.select_by_index(indices_in_box)

print(f"Puntos después del recorte: {len(buddha_pcd.points)}")

o3d.io.write_point_cloud(f"{DATASETS_PATH}/{dataset_name}/data/results/buddha-pcd.ply", buddha_pcd)
# Out:
# Puntos después del recorte: 3250919
# True

# %%
nbn = 20
std_ratio = 1

buddha_pcd_cleaned, ind = buddha_pcd.remove_statistical_outlier(
    nb_neighbors=nbn, std_ratio=std_ratio
)

print(f"Puntos finales después de la limpieza: {len(buddha_pcd_cleaned.points)}")
o3d.io.write_point_cloud(f"{DATASETS_PATH}/{dataset_name}/data/results/buddha-pcd-cleaned.ply", buddha_pcd_cleaned)
# Out:
# Puntos finales después de la limpieza: 3136190
# True
